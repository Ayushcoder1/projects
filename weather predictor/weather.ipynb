# %%
import pandas as pd
import numpy as np
data = pd.read_csv("local_weather.csv", index_col = "DATE")
data.head()
# Out:
#                 STATION                                  NAME  ACMH  ACSH  \
# DATE
# 1960-01-01  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-02  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-03  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-04  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
# 1960-01-05  USW00023230  OAKLAND INTERNATIONAL AIRPORT, CA US   NaN   NaN
#
#             AWND  DAPR  FMTM  FRGT  MDPR  PGTM  ...  WT01  WT02  WT03  WT04  \
# DATE                                            ...
# 1960-01-01   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-02   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-03   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-04   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN
# 1960-01-05   NaN   NaN   NaN   NaN   NaN   NaN  ...   1.0   NaN   NaN   NaN
#
# ...

# %%
data.isnull().sum()/data.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.653360
# ACSH       0.653360
# AWND       0.522451
# DAPR       0.999525
# FMTM       0.870099
# FRGT       0.999881
# MDPR       0.999525
# PGTM       0.495106
# PRCP       0.016668
# SNOW       0.324990
# SNWD       0.317634
# TAVG       0.879174
# TMAX       0.000534
# TMIN       0.000593
# TSUN       0.931728
# WDF1       0.653360
# WDF2       0.522392
# WDF5       0.527552
# WDFG       0.746901
# WSF1       0.653360
# WSF2       0.522332
# WSF5       0.527552
# WSFG       0.746901
# WT01       0.779939
# WT02       0.980248
# WT03       0.992941
# WT04       0.999763
# WT05       0.998339
# WT07       0.999881
# WT08       0.810368
# WT09       0.999881
# WT16       0.884038
# WT18       0.999822
# dtype: float64

# %%
imp_data = data[["PRCP", "TMAX", "TMIN"]].copy()
imp_data
# Out:
#             PRCP  TMAX  TMIN
# DATE
# 1960-01-01   0.0  49.0  30.0
# 1960-01-02   0.0  49.0  29.0
# 1960-01-03   0.0  54.0  35.0
# 1960-01-04   0.0  54.0  36.0
# 1960-01-05   0.0  55.0  33.0
# ...          ...   ...   ...
# 2022-01-24   0.0  60.0  39.0
# 2022-01-25   0.0  57.0  43.0
# 2022-01-26   0.0  57.0  41.0
# 2022-01-27   0.0  67.0  39.0
# 2022-01-28   0.0  64.0  39.0
#
# [16859 rows x 3 columns]

# %%
imp_data["PRCP"] = imp_data["PRCP"].fillna(0)
imp_data["PRCP"].value_counts()
# Out:
# PRCP
# 0.00    13945
# 0.01      438
# 0.02      199
# 0.03      122
# 0.04      102
#         ...
# 1.29        1
# 1.73        1
# 1.05        1
# 1.38        1
# 1.02        1
# Name: count, Length: 176, dtype: int64

# %%
imp_data = imp_data.ffill()
imp_data.isnull().sum()/imp_data.shape[0]
# Out:
# PRCP    0.0
# TMAX    0.0
# TMIN    0.0
# dtype: float64

# %%
imp_data.index = pd.to_datetime(imp_data.index)
imp_data.index
# Out:
# DatetimeIndex(['1960-01-01', '1960-01-02', '1960-01-03', '1960-01-04',
#                '1960-01-05', '1960-01-06', '1960-01-07', '1960-01-08',
#                '1960-01-09', '1960-01-10',
#                ...
#                '2022-01-19', '2022-01-20', '2022-01-21', '2022-01-22',
#                '2022-01-23', '2022-01-24', '2022-01-25', '2022-01-26',
#                '2022-01-27', '2022-01-28'],
#               dtype='datetime64[ns]', name='DATE', length=16859, freq=None)

# %%
imp_data[["TMAX", "TMIN"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
imp_data["PRCP"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
imp_data["target"] = imp_data.shift(-1)["TMAX"]
imp_data = imp_data.iloc[:-1, :].copy()
imp_data
imp_data.isnull().sum()
# Out:
# PRCP      0
# TMAX      0
# TMIN      0
# target    0
# dtype: int64

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=0.1)
predictors = ["PRCP", "TMAX", "TMIN"]
train = imp_data.loc[:"2020-12-31"]
test = imp_data.loc["2021-01-01":]

# %%
reg.fit(train[predictors], train["target"])
predictions = reg.predict(test[predictors])
from sklearn.metrics import mean_squared_error
mean_squared_error(test["target"], predictions)
# Out:
# 20.560668548118755

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
combined.columns = ["actual", "predictions"]
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
def predict(predictors, train, test, reg):

    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])

    error = mean_squared_error(test["target"], predictions)
    
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)], axis=1)
    combined.columns = ["actual", "predictions"]
    return error, combined

# %%
error, combined = predict(predictors, train, test, reg)
print(error)
combined.plot()
# Out:
# 20.560668548118755
# <Axes: xlabel='DATE'>

# %%
def least_square_soln(target, data, n):
    A = data[:n].drop(columns=target).values 
    A = np.hstack([np.ones((A.shape[0], 1)), A])
    b = data[target][:n].values
    
    At = np.transpose(A)
    AAt = np.dot(At, A)
    Atb = np.dot(At, b)
    
    AAt_inv = np.linalg.inv(AAt)
    feature_val = np.dot(AAt_inv, Atb)
    return feature_val

def mean_square_error(feature_val, data, date, target):
    mse = 0
    real = data[date: ][target]
    p = data[date: ][target].values
    test1 = data[date: ]
    test = data[date: ].drop(columns=target).values
    test = np.hstack([np.ones((test.shape[0], 1)), test])
    
    pdt = np.dot(test, feature_val)
    pred = pd.Series(pdt, index=test1.index)
    for i in range(len(pdt)):
        mse += (p[i] - pdt[i]) ** 2
    mse = mse/len(pdt)
    return mse, pred, real

# %%
feature_val = least_square_soln("target", imp_data, "2020-12-31")
mse, pred, real = mean_square_error(feature_val, imp_data, "2021-01-01", "target")
print("Mean-Square Error: ",mse)
combined = pd.concat([real, pred], axis=1)
combined.columns = ["actual", "predictions"]
combined.plot()
# Out:
# Mean-Square Error:  20.56069843323309
# <Axes: xlabel='DATE'>

# %%
print(reg.coef_, reg.intercept_)
print(feature_val)
# Out:
# [-2.20730384  0.72113834  0.17969047] 9.350104632300159
# [ 9.35021623 -2.20773562  0.72113526  0.17969267]
